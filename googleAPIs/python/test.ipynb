# %%
# !pip3 install googlemaps
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#   Using cached googlemaps-4.6.0-py3-none-any.whl
# ...
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# ...
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.0/139.0 KB 1.4 MB/s eta 0:00:00a 0:00:01
# ...
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...

# %%
import constants

# print(constants.API_TOKEN)

import googlemaps
from datetime import datetime
# Out:
# AIzaSyAeETEYnCGZ_GjKjmdVl0Jw7YXEkDplB3k

# %%
gmaps = googlemaps.Client(key=constants.API_TOKEN)

# %%
# Geocoding an address
geocode_result = gmaps.geocode(address='116台北市文山區指南路二段64號', language='zh-TW')
f = open('geocode_result.txt', 'w')
f.write(str(geocode_result))
f.close()

# %%
# Look up an address with reverse geocoding
reverse_geocode_result = gmaps.reverse_geocode((40.714224, -73.961452))

# %%
# Request directions via public transit
now = datetime.now()
directions_result = gmaps.directions("政治大學",
                                     "台灣大學",
                                     mode="transit",
                                     departure_time=now)
f = open("directions_result.txt", "w")
f.write(str(directions_result))
f.close()

# %%
for i in range(len(directions_result)):
    for key in directions_result[i]:
        print(key)
        #for kkey in directions_result[i][key]:
            #print(directions_result[i][key][kkey])
print("-----------------------------------------------------")
print(directions_result[0]['legs'][0]['steps'][0])
print("-----------------------------------------------------")
directions_result[0]['legs'][0]['steps'][1]
# Out:
# bounds
# copyrights
# fare
# legs
# overview_polyline
# summary
# warnings
# waypoint_order
# -----------------------------------------------------
# ...

# %%
polylines = []
for i in range(len(directions_result[0]['legs'][0]['steps'])):
    print(i)
    # for k in directions_result[0]['legs'][0]['steps'][i]:
    #     print(k)
    # if 'step' not in directions_result[0]['legs'][0]['steps'][i]:
    #     # print(directions_result[0]['legs'][0]['steps'][i])
    #     continue
    print(directions_result[0]['legs'][0]['steps'][i]['polyline']['points'])
    polylines.append(directions_result[0]['legs'][0]['steps'][i]['polyline']['points'])
# Out:
# 0
# wjowCmi`eVOCCLMA@G@Gc@N
# 1
# ...

# %%
convert = googlemaps.convert

lat_longs = []
for i in range(len(polylines)):
    lat_longs.append(convert.decode_polyline(polylines[i]))

lat_longs
# Out:
# [[{'lat': 24.98748, 'lng': 121.57607000000002},
#   {'lat': 24.987560000000002, 'lng': 121.57609000000001},
#   {'lat': 24.98758, 'lng': 121.57602000000001},
#   {'lat': 24.987650000000002, 'lng': 121.57603},
#   {'lat': 24.987640000000003, 'lng': 121.57607000000002},
#   {'lat': 24.987630000000003, 'lng': 121.57611000000001},
#   {'lat': 24.987810000000003, 'lng': 121.57603}],
#  [{'lat': 24.987810000000003, 'lng': 121.57605000000001},
#   {'lat': 24.987820000000003, 'lng': 121.57607000000002},
#   {'lat': 24.98758, 'lng': 121.57617},
#   {'lat': 24.9876, 'lng': 121.57606000000001},
#   {'lat': 24.98767, 'lng': 121.57570000000001},
#   {'lat': 24.98767, 'lng': 121.57568},
#   {'lat': 24.987710000000003, 'lng': 121.57546},
#   {'lat': 24.987830000000002, 'lng': 121.57487},
#   {'lat': 24.987940000000002, 'lng': 121.57427000000001},
#   {'lat': 24.98796, 'lng': 121.57415},
#   {'lat': 24.987990000000003, 'lng': 121.57405000000001},
# ...

# %%
f = open('lat_longs.txt', 'w')
f.write(str(lat_longs))
# Out:
# 21107
