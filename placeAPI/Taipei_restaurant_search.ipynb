# %%
# example of using getLocation()

import placesQuery
import os
import json

radius = 150

# function getlocation: 
# parameters: 
#   lat: int, no default
#   lon: int, no default
#   radius: int, default = "200"
#
# returns  a list of informations about each restautant in Json format

# test 1
# resultList = placesQuery.getLocation(25.01491,121.53422,radius)

# save the results into files


# north taipei
# resultList = placesQuery.honeycombSearch(25.068704, 121.509770,25.040142, 121.529747,150) # first part
# resultList = placesQuery.honeycombSearch(25.068704, 121.529747,25.040142, 121.550018,150) # second part
# resultList = placesQuery.honeycombSearch(25.068704, 121.550018,25.040142, 121.568227,150) # third part 

# south Taipei
# resultList = placesQuery.honeycombSearch(25.040142, 121.509770,25.022970, 121.543416,120)
# resultList = placesQuery.honeycombSearch(25.040142, 121.543416,25.022970, 121.568227,120)



# resultList = placesQuery.honeycombSearch(25.068704, 121.509770,25.026142, 121.569747,150) # half taipei city

with open(os.path.join('results','TaipeiCity.json'), 'w') as f:
    f.write(json.dumps(resultList))


# print the names and ratings of the places got from query

counter = 0
print(len(resultList))
for i in resultList:
    print(i["name"])
    counter += 1
print(counter)
# Out:
# 25.040142 121.543416
# the 2 th query
# success
# 25.040142 121.54547783328132
# 25.040142 121.54753966656266
# the 2 th query
# success
# 25.040142 121.54960149984399
# the 2 th query
# success
# 25.040142 121.55166333312532
# the 2 th query
# success
# the 3 th query
# success
# 25.040142 121.55372516640665
# the 2 th query
# success
# the 3 th query
# success
# 25.040142 121.55578699968798
# the 2 th query
# success
# the 3 th query
# success
# 25.040142 121.55784883296931
# 25.040142 121.55991066625064
# 25.040142 121.56197249953198
# the 2 th query
# success
# 25.040142 121.5640343328133
# 25.040142 121.56609616609464
# the 2 th query
# success
# the 3 th query
# success
# 25.040142 121.56815799937597
# the 2 th query
# success
# 25.038522 121.54238508335933
# 25.038522 121.54444691664067
# 25.038522 121.546508749922
# the 2 th query
# success
# 25.038522 121.54857058320333
# 25.038522 121.55063241648466
# the 2 th query
# success
# 25.038522 121.55269424976599
# the 2 th query
# ...

# %%
print(len(resultList))
for i in resultList:
    print(i["name"])
    counter += 1
print(counter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pp/4qhsjngd0ynbxmsb2k065s980000gn/T/ipykernel_74640/4159556598.py in <module>
# ----> 1 print(len(resultList))
#       2 for i in resultList:
#       3     print(i["name"])
#       4     counter += 1
#       5 print(counter)
#
# NameError: name 'resultList' is not defined

# %%
# Out:
# 3

# %%
# example of using getLocation()

import placesQuery
import os
import json

radius = 500

# function getlocation: 
# parameters: 
#   lat: int, no default
#   lon: int, no default
#   radius: int, default = "200"
#
# returns  a list of informations about each restautant in Json format

# test 1
resultList = placesQuery.getLocation(23.563335, 119.628501,radius)

print(json.dumps(resultList))

for i in resultList:
    print(i)
# Out:
# [{"business_status": "OPERATIONAL", "geometry": {"location": {"lat": 23.56116639999999, "lng": 119.6296181}, "viewport": {"northeast": {"lat": 23.5624528302915, "lng": 119.6311759302915}, "southwest": {"lat": 23.5597548697085, "lng": 119.6284779697085}}}, "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png", "icon_background_color": "#FF9E67", "icon_mask_base_uri": "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet", "name": "\u63ac\u5473 Vivi Caf\u00e9", "opening_hours": {"open_now": true}, "photos": [{"height": 3024, "html_attributions": ["<a href=\"https://maps.google.com/maps/contrib/106216114248896198827\">Wei</a>"], "photo_reference": "AeJbb3f_oz1lfYehQZRExEPzTn1DrHwXWIH9E4T_8fztWSz-fsz9Q4VHTuNQmoULHcGbBBBso6p_SCdrHFofbiIKHoHmcjPfq_i0LAAycwV2L5c2O-0PVR2TZWuI0MdbbDxmDJvplvxPAP1HBTqTLVc7W9bSzY-j1XONqSqCh6zXZXQ_H7VE", "width": 4032}], "place_id": "ChIJNQ_jnxdFbDQReuddPNbEu_8", "plus_code": {"compound_code": "HJ6H+FR \u53f0\u7
# ...

# %%
print(type((json.dumps(resultList))))
# Out:
# <class 'str'>

# %%
for i in resultList:
    print(i['name'])
    print(i['types'])
# Out:
# ['restaurant', 'point_of_interest', 'food', 'establishment']
